# %%
#!pip install plotly
# !pip install chart_studio
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Dependencies and Setup
# %matplotlib inline
# %matplotlib notebook

# %%
# Dependencies and Setup
import pandas as pd
import os
import json
import requests
from pprint import pprint
import numpy as np

# for plotting
import matplotlib.pyplot as plt

#import plotly.plotly as py
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode,plot ,iplot,plot_mpl

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Read CSV FILE

employment_2018_data="state_M2018.csv"
Bls_Employment_2018_data=pd.read_csv(employment_2018_data)


print(len(Bls_Employment_2018_data))
# Out:
# 36897

# %%
Bls_Employment_2018_data.head()
# Out:
#    AREA  ST    STATE OCC_CODE                        OCC_TITLE OCC_GROUP  \
# 0     1  AL  Alabama  00-0000                  All Occupations     total
# 1     1  AL  Alabama  11-0000           Management Occupations     major
# 2     1  AL  Alabama  11-1011                 Chief Executives  detailed
# 3     1  AL  Alabama  11-1021  General and Operations Managers  detailed
# 4     1  AL  Alabama  11-1031                      Legislators  detailed
#
#      TOT_EMP EMP_PRSE JOBS_1000 LOC_Q  ...   H_MEDIAN H_PCT75 H_PCT90 A_PCT10  \
# 0  1,943,760      0.4  1000.000  1.00  ...      16.22   25.63   38.28  18,030
# 1     73,860      1.1    38.001  0.72  ...      46.01   63.87   90.06  48,650
# 2      1,390      5.6     0.716  0.53  ...      91.31       #       #  79,530
# 3     28,600      1.8    14.712  0.93  ...      48.55   70.79       #  50,180
# 4        970      6.4     0.498  1.43  ...          *       *       *  16,310
#
#    A_PCT25 A_MEDIAN  A_PCT75  A_PCT90 ANNUAL HOURLY
# ...

# %%
Bls_Employment_2018_final=Bls_Employment_2018_data[["ST","STATE","OCC_CODE","OCC_TITLE","TOT_EMP","JOBS_1000","LOC_Q","A_MEAN"]]
Bls_Employment_2018_final.head()
# Out:
#    ST    STATE OCC_CODE                        OCC_TITLE    TOT_EMP JOBS_1000  \
# 0  AL  Alabama  00-0000                  All Occupations  1,943,760  1000.000
# 1  AL  Alabama  11-0000           Management Occupations     73,860    38.001
# 2  AL  Alabama  11-1011                 Chief Executives      1,390     0.716
# 3  AL  Alabama  11-1021  General and Operations Managers     28,600    14.712
# 4  AL  Alabama  11-1031                      Legislators        970     0.498
#
#   LOC_Q   A_MEAN
# 0  1.00   43,790
# 1  0.72  109,680
# 2  0.53  204,590
# 3  0.93  118,440
# 4  1.43   31,760

# %%
Bls_Employment_2018_final.columns
# Out:
# Index(['ST', 'STATE', 'OCC_CODE', 'OCC_TITLE', 'TOT_EMP', 'JOBS_1000', 'LOC_Q',
#        'A_MEAN'],
#       dtype='object')

# %%
Bls_Employment_2018_final.columns=['STATE_CODE','STATE_NAME','OCCUPATION_CODE','OCCUPATION_TITLE','TOTAL_EMPLOYMENT','JOBS_PER_1000','LOCATION_QUOTIENT','ANNUAL_MEAN_WAGE']

Bls_Employment_2018_final.columns
# Out:
# Index(['STATE_CODE', 'STATE_NAME', 'OCCUPATION_CODE', 'OCCUPATION_TITLE',
#        'TOTAL_EMPLOYMENT', 'JOBS_PER_1000', 'LOCATION_QUOTIENT',
#        'ANNUAL_MEAN_WAGE'],
#       dtype='object')

# %%
Bls_Employment_2018_final.head()
# Out:
#   STATE_CODE STATE_NAME OCCUPATION_CODE                 OCCUPATION_TITLE  \
# 0         AL    Alabama         00-0000                  All Occupations
# 1         AL    Alabama         11-0000           Management Occupations
# 2         AL    Alabama         11-1011                 Chief Executives
# 3         AL    Alabama         11-1021  General and Operations Managers
# 4         AL    Alabama         11-1031                      Legislators
#
#   TOTAL_EMPLOYMENT JOBS_PER_1000 LOCATION_QUOTIENT ANNUAL_MEAN_WAGE
# 0        1,943,760      1000.000              1.00           43,790
# 1           73,860        38.001              0.72          109,680
# 2            1,390         0.716              0.53          204,590
# 3           28,600        14.712              0.93          118,440
# 4              970         0.498              1.43           31,760

# %%
Bls_Employment_2018_final['text'] = Bls_Employment_2018_final['STATE_NAME'] + '<br>' + \
    'JOBS_PER_1000 :' + Bls_Employment_2018_final['JOBS_PER_1000'] +'<br>' + \
    ' LOCATION_QUOTIENT : ' + Bls_Employment_2018_final['LOCATION_QUOTIENT'] + '<br>' + \
    'ANNUAL_MEAN_WAGE :$' + Bls_Employment_2018_final['ANNUAL_MEAN_WAGE']
Bls_Employment_2018_final
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       STATE_CODE      STATE_NAME OCCUPATION_CODE  \
# 0             AL         Alabama         00-0000
# 1             AL         Alabama         11-0000
# 2             AL         Alabama         11-1011
# 3             AL         Alabama         11-1021
# 4             AL         Alabama         11-1031
# 5             AL         Alabama         11-2011
# 6             AL         Alabama         11-2021
# 7             AL         Alabama         11-2022
# 8             AL         Alabama         11-2031
# 9             AL         Alabama         11-3011
# 10            AL         Alabama         11-3021
# ...

# %%
#occupationcode = ["13-2051","15-1132","13-1161","17-2141","11-3021","11-9041","15-1141","11-2021","15-1122","11-3121","11-2022","17-1011","27-1024","17-2051","27-3031"]

occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
bls3=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')

bls3
# Out:
#       STATE_CODE      STATE_NAME OCCUPATION_CODE  \
# 38            AL         Alabama         13-1041
# 39            AL         Alabama         13-1051
# 43            AL         Alabama         13-1111
# 47            AL         Alabama         13-1151
# 48            AL         Alabama         13-1161
# 65            AL         Alabama         15-1121
# 66            AL         Alabama         15-1122
# 67            AL         Alabama         15-1131
# 68            AL         Alabama         15-1132
# 71            AL         Alabama         15-1141
# 85            AL         Alabama         17-2011
# 87            AL         Alabama         17-2051
# 88            AL         Alabama         17-2061
# 89            AL         Alabama         17-2071
# 96            AL         Alabama         17-2141
# 774           AK          Alaska         13-1041
# 775           AK          Alaska         13-1051
# 779           AK          Alaska         13-1111
# ...

# %%
#Geographical Plotting
#Choropleth US Maps Using Plotly Library.

# %%
# Now we need to begin to build our data dictionary. Easiest way to do this is to use the dict() function of the general form:
# type = 'choropleth',
# locations = list of states
# locationmode = 'USA-states'
# colorscale= 
# Either a predefined string:
# 'pairs' | 'Greys' | 'Greens' | 'Bluered' | 'Hot' | 'Picnic' | 'Portland' | 'Jet' | 'RdBu' | 'Blackbody' | 'Earth' | 'Electric' | 'YIOrRd' | 'YIGnBu'

# %%
bls3['text'] = bls3['STATE_NAME'] + '<br>' + \
    'JOBS_PER_1000 :' + bls3['JOBS_PER_1000'] +'<br>' + \
    ' LOCATION_QUOTIENT : ' + bls3['LOCATION_QUOTIENT'] + '<br>' + \
    'ANNUAL_MEAN_WAGE :' + bls3['ANNUAL_MEAN_WAGE']
bls3
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       STATE_CODE      STATE_NAME OCCUPATION_CODE  \
# 38            AL         Alabama         13-1041
# 39            AL         Alabama         13-1051
# 43            AL         Alabama         13-1111
# 47            AL         Alabama         13-1151
# 48            AL         Alabama         13-1161
# 65            AL         Alabama         15-1121
# 66            AL         Alabama         15-1122
# 67            AL         Alabama         15-1131
# 68            AL         Alabama         15-1132
# 71            AL         Alabama         15-1141
# 85            AL         Alabama         17-2011
# ...

# %%
data = dict(type='choropleth',
            colorscale = 'Portland',
            locations = bls3['STATE_CODE'],
            z = bls3['TOTAL_EMPLOYMENT'],
            locationmode = 'USA-states',
            text = bls3['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
            )

# %%
layout = dict(title = '2018 US Employment by State',
              geo = dict(scope='usa'))

# %%
choromap = go.Figure(data = [data],layout = layout)

# %%
plot(choromap)
# Out:
# 'temp-plot.html'

# %%
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="5f4f8c67-f156-44a7-b733-8b5ab9aeb390" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5f4f8c67-f156-44a7-b733-8b5ab9aeb390")) {
#                     Plotly.newPlot(
#                         '5f4f8c67-f156-44a7-b733-8b5ab9aeb390',
# ...

# %%
#seperate dataframe for each occupation code

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]

# %%
#1
#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["13-1161"]
Bls_Employment_2018_final_1=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_1
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE  \
# 48            AL               Alabama         13-1161
# 784           AK                Alaska         13-1161
# 1346          AZ               Arizona         13-1161
# 2094          AR              Arkansas         13-1161
# 2786          CA            California         13-1161
# 3599          CO              Colorado         13-1161
# 4354          CT           Connecticut         13-1161
# 5044          DE              Delaware         13-1161
# 5588          DC  District of Columbia         13-1161
# 6117          FL               Florida         13-1161
# 6912          GA               Georgia         13-1161
# 7666          HI                Hawaii         13-1161
# 8262          ID                 Idaho         13-1161
# 8910          IL              Illinois         13-1161
# 9694          IN               Indiana         13-1161
# 10465         IA                  Iowa         13-1161
# ...

# %%
#plotting for 1st occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations =Bls_Employment_2018_final_1['STATE_CODE'],
            z = Bls_Employment_2018_final_1['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_1['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
            )


layout = dict(title = '2018 US Employment for Market Research Analysts and Marketing Specialist by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Market Research Analysts and Marketing Special-1.html')
#plot(choromap)
iplot(choromap)
# Out:
# <div>
#
#
#             <div id="3a7a872b-2803-4329-a5ec-dc77433bc4f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3a7a872b-2803-4329-a5ec-dc77433bc4f8")) {
#                     Plotly.newPlot(
#                         '3a7a872b-2803-4329-a5ec-dc77433bc4f8',
# ...

# %%
#2
#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["13-1151"]
Bls_Employment_2018_final_2=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_2
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE  \
# 47            AL               Alabama         13-1151
# 783           AK                Alaska         13-1151
# 1345          AZ               Arizona         13-1151
# 2093          AR              Arkansas         13-1151
# 2785          CA            California         13-1151
# 3598          CO              Colorado         13-1151
# 4353          CT           Connecticut         13-1151
# 5043          DE              Delaware         13-1151
# 5587          DC  District of Columbia         13-1151
# 6116          FL               Florida         13-1151
# 6911          GA               Georgia         13-1151
# 7665          HI                Hawaii         13-1151
# 8261          ID                 Idaho         13-1151
# 8909          IL              Illinois         13-1151
# 9693          IN               Indiana         13-1151
# 10464         IA                  Iowa         13-1151
# ...

# %%
#plotting for 2st occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_2['STATE_CODE'],
            z = Bls_Employment_2018_final_2['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_2['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
            )


layout = dict(title = '2018 US Employment for Training and Development Specialists by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Training and Development Specialists-2')



iplot(choromap)
# Out:
# <div>
#
#
#             <div id="38a4b3de-0bff-4c1a-98fc-694d52b5808c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("38a4b3de-0bff-4c1a-98fc-694d52b5808c")) {
#                     Plotly.newPlot(
#                         '38a4b3de-0bff-4c1a-98fc-694d52b5808c',
# ...

# %%
#3
#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["13-1041"]
Bls_Employment_2018_final_3=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_3
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE     OCCUPATION_TITLE  \
# 38            AL               Alabama         13-1041  Compliance Officers
# 774           AK                Alaska         13-1041  Compliance Officers
# 1336          AZ               Arizona         13-1041  Compliance Officers
# 2084          AR              Arkansas         13-1041  Compliance Officers
# 2775          CA            California         13-1041  Compliance Officers
# 3589          CO              Colorado         13-1041  Compliance Officers
# 4344          CT           Connecticut         13-1041  Compliance Officers
# 5034          DE              Delaware         13-1041  Compliance Officers
# 5578          DC  District of Columbia         13-1041  Compliance Officers
# 6107          FL               Florida         13-1041  Compliance Officers
# 6902          GA               Georgia         13-1041  Compliance Officers
# ...

# %%
#plotting for 3rd occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_3['STATE_CODE'],
            z = Bls_Employment_2018_final_3['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_3['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
            )


layout = dict(title = '2018 US Employment for Compliance Officers by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Compliance Officers-3.html')


iplot(choromap)
# Out:
# <div>
#
#
#             <div id="f967395d-aaf1-42fc-8566-ea03df5a8cd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f967395d-aaf1-42fc-8566-ea03df5a8cd7")) {
#                     Plotly.newPlot(
#                         'f967395d-aaf1-42fc-8566-ea03df5a8cd7',
# ...

# %%
#4
#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["13-1111"]
Bls_Employment_2018_final_4=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_4
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE     OCCUPATION_TITLE  \
# 43            AL               Alabama         13-1111  Management Analysts
# 779           AK                Alaska         13-1111  Management Analysts
# 1341          AZ               Arizona         13-1111  Management Analysts
# 2089          AR              Arkansas         13-1111  Management Analysts
# 2781          CA            California         13-1111  Management Analysts
# 3594          CO              Colorado         13-1111  Management Analysts
# 4349          CT           Connecticut         13-1111  Management Analysts
# 5039          DE              Delaware         13-1111  Management Analysts
# 5583          DC  District of Columbia         13-1111  Management Analysts
# 6112          FL               Florida         13-1111  Management Analysts
# 6907          GA               Georgia         13-1111  Management Analysts
# ...

# %%
#plotting for 4th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_4['STATE_CODE'],
            z = Bls_Employment_2018_final_4['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_4['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
            
            )


layout = dict(title = '2018 US Employment for Management Analysts by State',
              geo = dict(scope='usa'))

plot(choromap,filename='C:/Users/sonal/Desktop/project1/Management Analysts-4.html')
choromap = go.Figure(data = [data],layout = layout)

iplot(choromap)
# Out:
# <div>
#
#
#             <div id="db3b08be-01fc-4047-bb5b-691b7e44f5a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db3b08be-01fc-4047-bb5b-691b7e44f5a7")) {
#                     Plotly.newPlot(
#                         'db3b08be-01fc-4047-bb5b-691b7e44f5a7',
# ...

# %%
#5

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["13-1051"]
Bls_Employment_2018_final_5=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_5
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE OCCUPATION_TITLE  \
# 39            AL               Alabama         13-1051  Cost Estimators
# 775           AK                Alaska         13-1051  Cost Estimators
# 1337          AZ               Arizona         13-1051  Cost Estimators
# 2085          AR              Arkansas         13-1051  Cost Estimators
# 2776          CA            California         13-1051  Cost Estimators
# 3590          CO              Colorado         13-1051  Cost Estimators
# 4345          CT           Connecticut         13-1051  Cost Estimators
# 5035          DE              Delaware         13-1051  Cost Estimators
# 5579          DC  District of Columbia         13-1051  Cost Estimators
# 6108          FL               Florida         13-1051  Cost Estimators
# 6903          GA               Georgia         13-1051  Cost Estimators
# 7657          HI                Hawaii         13-1051  Cost Estimators
# ...

# %%
#plotting for 5th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_5['STATE_CODE'],
            z = Bls_Employment_2018_final_5['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_5['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
            
            )


layout = dict(title = '2018 US Employment for Cost Estimators by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Cost Estimators-5.html')

iplot(choromap)
# Out:
# <div>
#
#
#             <div id="6f37d236-9f94-4ad5-b88f-3f117e44ce5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f37d236-9f94-4ad5-b88f-3f117e44ce5c")) {
#                     Plotly.newPlot(
#                         '6f37d236-9f94-4ad5-b88f-3f117e44ce5c',
# ...

# %%
#6

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]

occupationcode = ["15-1132"]
Bls_Employment_2018_final_6=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_6
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE  \
# 68            AL               Alabama         15-1132
# 801           AK                Alaska         15-1132
# 1366          AZ               Arizona         15-1132
# 2114          AR              Arkansas         15-1132
# 2806          CA            California         15-1132
# 3618          CO              Colorado         15-1132
# 4374          CT           Connecticut         15-1132
# 5062          DE              Delaware         15-1132
# 5607          DC  District of Columbia         15-1132
# 6137          FL               Florida         15-1132
# 6932          GA               Georgia         15-1132
# 7686          HI                Hawaii         15-1132
# 8282          ID                 Idaho         15-1132
# 8930          IL              Illinois         15-1132
# 9714          IN               Indiana         15-1132
# 10484         IA                  Iowa         15-1132
# ...

# %%
#plotting for 6th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_6['STATE_CODE'],
            z = Bls_Employment_2018_final_6['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_6['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Software Developers, Applications by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Software Developers, Applications-6.html')


iplot(choromap)
# Out:
# <div>
#
#
#             <div id="99ac4b5d-f2b6-4f2f-94c2-b086d9306b4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("99ac4b5d-f2b6-4f2f-94c2-b086d9306b4d")) {
#                     Plotly.newPlot(
#                         '99ac4b5d-f2b6-4f2f-94c2-b086d9306b4d',
# ...

# %%
#7

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["15-1141"]
Bls_Employment_2018_final_7=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_7
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE  \
# 71            AL               Alabama         15-1141
# 804           AK                Alaska         15-1141
# 1369          AZ               Arizona         15-1141
# 2117          AR              Arkansas         15-1141
# 2809          CA            California         15-1141
# 3621          CO              Colorado         15-1141
# 4377          CT           Connecticut         15-1141
# 5064          DE              Delaware         15-1141
# 5610          DC  District of Columbia         15-1141
# 6140          FL               Florida         15-1141
# 6935          GA               Georgia         15-1141
# 7689          HI                Hawaii         15-1141
# 8285          ID                 Idaho         15-1141
# 8933          IL              Illinois         15-1141
# 9717          IN               Indiana         15-1141
# 10487         IA                  Iowa         15-1141
# ...

# %%
#plotting for 7th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_7['STATE_CODE'],
            z = Bls_Employment_2018_final_7['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_7['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Database Administrators by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Database Administrators-7.html')


iplot(choromap)
# Out:
# <div>
#
#
#             <div id="f7e3170b-7992-4f3b-afd2-dd8709002cde" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f7e3170b-7992-4f3b-afd2-dd8709002cde")) {
#                     Plotly.newPlot(
#                         'f7e3170b-7992-4f3b-afd2-dd8709002cde',
# ...

# %%
#8

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["15-1122"]
Bls_Employment_2018_final_8=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_8
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE  \
# 66            AL               Alabama         15-1122
# 799           AK                Alaska         15-1122
# 1364          AZ               Arizona         15-1122
# 2112          AR              Arkansas         15-1122
# 2804          CA            California         15-1122
# 3616          CO              Colorado         15-1122
# 4372          CT           Connecticut         15-1122
# 5060          DE              Delaware         15-1122
# 5605          DC  District of Columbia         15-1122
# 6135          FL               Florida         15-1122
# 6930          GA               Georgia         15-1122
# 7684          HI                Hawaii         15-1122
# 8280          ID                 Idaho         15-1122
# 8928          IL              Illinois         15-1122
# 9712          IN               Indiana         15-1122
# 10482         IA                  Iowa         15-1122
# ...

# %%
#plotting for 8th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_8['STATE_CODE'],
            z = Bls_Employment_2018_final_8['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_8['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Information Security Analysts by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Information Security Analysts-8.html')

iplot(choromap)
# Out:
# <div>
#
#
#             <div id="54da17b5-0c95-48fd-ab99-3ac26ae7575a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54da17b5-0c95-48fd-ab99-3ac26ae7575a")) {
#                     Plotly.newPlot(
#                         '54da17b5-0c95-48fd-ab99-3ac26ae7575a',
# ...

# %%
#9

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["15-1121"]
Bls_Employment_2018_final_9=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_9
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE  \
# 65            AL               Alabama         15-1121
# 798           AK                Alaska         15-1121
# 1363          AZ               Arizona         15-1121
# 2111          AR              Arkansas         15-1121
# 2803          CA            California         15-1121
# 3615          CO              Colorado         15-1121
# 4371          CT           Connecticut         15-1121
# 5059          DE              Delaware         15-1121
# 5604          DC  District of Columbia         15-1121
# 6134          FL               Florida         15-1121
# 6929          GA               Georgia         15-1121
# 7683          HI                Hawaii         15-1121
# 8279          ID                 Idaho         15-1121
# 8927          IL              Illinois         15-1121
# 9711          IN               Indiana         15-1121
# 10481         IA                  Iowa         15-1121
# ...

# %%
#plotting for 9th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_9['STATE_CODE'],
            z = Bls_Employment_2018_final_9['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_9['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Computer Systems Analysts by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Computer Systems Analysts-9.html')


iplot(choromap)
# Out:
# <div>
#
#
#             <div id="6f776b47-20b1-43e6-8d3e-f8e95f077ca7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6f776b47-20b1-43e6-8d3e-f8e95f077ca7")) {
#                     Plotly.newPlot(
#                         '6f776b47-20b1-43e6-8d3e-f8e95f077ca7',
# ...

# %%
#10

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]

occupationcode = ["15-1131"]
Bls_Employment_2018_final_10=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_10
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE      OCCUPATION_TITLE  \
# 67            AL               Alabama         15-1131  Computer Programmers
# 800           AK                Alaska         15-1131  Computer Programmers
# 1365          AZ               Arizona         15-1131  Computer Programmers
# 2113          AR              Arkansas         15-1131  Computer Programmers
# 2805          CA            California         15-1131  Computer Programmers
# 3617          CO              Colorado         15-1131  Computer Programmers
# 4373          CT           Connecticut         15-1131  Computer Programmers
# 5061          DE              Delaware         15-1131  Computer Programmers
# 5606          DC  District of Columbia         15-1131  Computer Programmers
# 6136          FL               Florida         15-1131  Computer Programmers
# 6931          GA               Georgia         15-1131  Computer Programmers
# ...

# %%
#plotting for 10th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_10['STATE_CODE'],
            z = Bls_Employment_2018_final_10['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_10['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Computer Programmers by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Computer Programmers-10.html')


iplot(choromap)
# Out:
# <div>
#
#
#             <div id="4355b1f7-66a1-4dca-9a05-eeac87e66cf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4355b1f7-66a1-4dca-9a05-eeac87e66cf9")) {
#                     Plotly.newPlot(
#                         '4355b1f7-66a1-4dca-9a05-eeac87e66cf9',
# ...

# %%
#11

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["17-2141"]
Bls_Employment_2018_final_11=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_11
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE      OCCUPATION_TITLE  \
# 96            AL               Alabama         17-2141  Mechanical Engineers
# 826           AK                Alaska         17-2141  Mechanical Engineers
# 1394          AZ               Arizona         17-2141  Mechanical Engineers
# 2141          AR              Arkansas         17-2141  Mechanical Engineers
# 2838          CA            California         17-2141  Mechanical Engineers
# 3648          CO              Colorado         17-2141  Mechanical Engineers
# 4403          CT           Connecticut         17-2141  Mechanical Engineers
# 5080          DE              Delaware         17-2141  Mechanical Engineers
# 5634          DC  District of Columbia         17-2141  Mechanical Engineers
# 6169          FL               Florida         17-2141  Mechanical Engineers
# 6961          GA               Georgia         17-2141  Mechanical Engineers
# ...

# %%
#plotting for 11th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_11['STATE_CODE'],
            z = Bls_Employment_2018_final_11['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_11['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment by for Mechanical Engineers State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)

plot(choromap,filename='C:/Users/sonal/Desktop/project1/Mechanical Engineers-11.html')

iplot(choromap)
# Out:
# <div>
#
#
#             <div id="2f5d8e0f-2b27-4d39-a64f-b684e59d2c7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2f5d8e0f-2b27-4d39-a64f-b684e59d2c7e")) {
#                     Plotly.newPlot(
#                         '2f5d8e0f-2b27-4d39-a64f-b684e59d2c7e',
# ...

# %%
#12

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["17-2051"]
Bls_Employment_2018_final_12=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_12
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE OCCUPATION_TITLE  \
# 87            AL               Alabama         17-2051  Civil Engineers
# 818           AK                Alaska         17-2051  Civil Engineers
# 1386          AZ               Arizona         17-2051  Civil Engineers
# 2133          AR              Arkansas         17-2051  Civil Engineers
# 2829          CA            California         17-2051  Civil Engineers
# 3640          CO              Colorado         17-2051  Civil Engineers
# 4395          CT           Connecticut         17-2051  Civil Engineers
# 5075          DE              Delaware         17-2051  Civil Engineers
# 5626          DC  District of Columbia         17-2051  Civil Engineers
# 6160          FL               Florida         17-2051  Civil Engineers
# 6953          GA               Georgia         17-2051  Civil Engineers
# 7703          HI                Hawaii         17-2051  Civil Engineers
# ...

# %%
#plotting for  12th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_12['STATE_CODE'],
            z = Bls_Employment_2018_final_12['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_12['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Civil Engineers by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Civil Engineers-12.html')

iplot(choromap)
# Out:
# <div>
#
#
#             <div id="4ad927e6-fcea-410a-86ad-e6f113f3f4e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ad927e6-fcea-410a-86ad-e6f113f3f4e1")) {
#                     Plotly.newPlot(
#                         '4ad927e6-fcea-410a-86ad-e6f113f3f4e1',
# ...

# %%
#13

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["17-2061"]
Bls_Employment_2018_final_13=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_13
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE  \
# 88            AL               Alabama         17-2061
# 819           AK                Alaska         17-2061
# 1387          AZ               Arizona         17-2061
# 2134          AR              Arkansas         17-2061
# 2830          CA            California         17-2061
# 3641          CO              Colorado         17-2061
# 4396          CT           Connecticut         17-2061
# 5627          DC  District of Columbia         17-2061
# 6161          FL               Florida         17-2061
# 6954          GA               Georgia         17-2061
# 7704          HI                Hawaii         17-2061
# 8301          ID                 Idaho         17-2061
# 8954          IL              Illinois         17-2061
# 9736          IN               Indiana         17-2061
# 10505         IA                  Iowa         17-2061
# 11223         KS                Kansas         17-2061
# ...

# %%
#plotting for 13th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_13['STATE_CODE'],
            z = Bls_Employment_2018_final_13['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_13['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL_EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Computer Hardware Engineers by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Computer Hardware Engineers-13.html')


iplot(choromap)
# Out:
# <div>
#
#
#             <div id="08007a3c-2b27-447c-852f-9aa5c093db39" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("08007a3c-2b27-447c-852f-9aa5c093db39")) {
#                     Plotly.newPlot(
#                         '08007a3c-2b27-447c-852f-9aa5c093db39',
# ...

# %%
#14

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["17-2071"]
Bls_Employment_2018_final_14=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_14
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE      OCCUPATION_TITLE  \
# 89            AL               Alabama         17-2071  Electrical Engineers
# 820           AK                Alaska         17-2071  Electrical Engineers
# 1388          AZ               Arizona         17-2071  Electrical Engineers
# 2135          AR              Arkansas         17-2071  Electrical Engineers
# 2831          CA            California         17-2071  Electrical Engineers
# 3642          CO              Colorado         17-2071  Electrical Engineers
# 4397          CT           Connecticut         17-2071  Electrical Engineers
# 5076          DE              Delaware         17-2071  Electrical Engineers
# 5628          DC  District of Columbia         17-2071  Electrical Engineers
# 6162          FL               Florida         17-2071  Electrical Engineers
# 6955          GA               Georgia         17-2071  Electrical Engineers
# ...

# %%
#plotting for 14th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_14['STATE_CODE'],
            z = Bls_Employment_2018_final_14['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_14['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Electrical Engineers by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)
plot(choromap,filename='C:/Users/sonal/Desktop/project1/Electrical Engineers-14.html')


iplot(choromap)
# Out:
# <div>
#
#
#             <div id="c8e433b8-356b-42af-868a-89908fd1c9fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c8e433b8-356b-42af-868a-89908fd1c9fb")) {
#                     Plotly.newPlot(
#                         'c8e433b8-356b-42af-868a-89908fd1c9fb',
# ...

# %%
#15

#occupationcode=["13-1161","13-1151","13-1041","13-1111","13-1051","15-1132","15-1141","15-1122","15-1121","15-1131","17-2141","17-2051","17-2061","17-2071","17-2011"]
occupationcode = ["17-2011"]
Bls_Employment_2018_final_15=Bls_Employment_2018_final.query('OCCUPATION_CODE in @occupationcode')
Bls_Employment_2018_final_15=Bls_Employment_2018_final_15.replace("**",np.nan)

Bls_Employment_2018_final_15
# Out:
#       STATE_CODE            STATE_NAME OCCUPATION_CODE     OCCUPATION_TITLE  \
# 85            AL               Alabama         17-2011  Aerospace Engineers
# 816           AK                Alaska         17-2011  Aerospace Engineers
# 1383          AZ               Arizona         17-2011  Aerospace Engineers
# 2825          CA            California         17-2011  Aerospace Engineers
# 3637          CO              Colorado         17-2011  Aerospace Engineers
# 4392          CT           Connecticut         17-2011  Aerospace Engineers
# 5623          DC  District of Columbia         17-2011  Aerospace Engineers
# 6156          FL               Florida         17-2011  Aerospace Engineers
# 6950          GA               Georgia         17-2011  Aerospace Engineers
# 7702          HI                Hawaii         17-2011  Aerospace Engineers
# 8949          IL              Illinois         17-2011  Aerospace Engineers
# ...

# %%
#plotting for 15th occupation code

# %%
data = dict(type='choropleth',
            colorscale = 'Greens',
            locations = Bls_Employment_2018_final_15['STATE_CODE'],
            z = Bls_Employment_2018_final_15['TOTAL_EMPLOYMENT'].str.replace(",","").astype(float),
            locationmode = 'USA-states',
            text = Bls_Employment_2018_final_15['text'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"TOTAL EMPLOYMENT"}
    
            )


layout = dict(title = '2018 US Employment for Aerospace Engineers by State',
              geo = dict(scope='usa'))


choromap = go.Figure(data = [data],layout = layout)

plot(choromap,filename='C:/Users/sonal/Desktop/project1/Aerospace Engineers-15.html')


iplot(choromap)
# Out:
# <div>
#
#
#             <div id="1169301a-ae0e-4cbc-83d6-44cc399cf506" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1169301a-ae0e-4cbc-83d6-44cc399cf506")) {
#                     Plotly.newPlot(
#                         '1169301a-ae0e-4cbc-83d6-44cc399cf506',
# ...
